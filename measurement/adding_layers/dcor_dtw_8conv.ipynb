# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install dcor dtaidistance
# Out:
# Requirement already satisfied: dcor in /usr/local/lib/python3.6/dist-packages (0.3)
# Requirement already satisfied: dtaidistance in /usr/local/lib/python3.6/dist-packages (1.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from dcor) (1.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from dcor) (41.6.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.6/dist-packages (from dcor) (0.40.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dcor) (1.17.4)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from dtaidistance) (0.29.14)
# Requirement already satisfied: llvmlite>=0.25.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba->dcor) (0.30.0)

# %%
import os
import h5py
import time
import random

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import dcor
from dtaidistance import dtw

from sklearn.metrics import confusion_matrix, classification_report

# %%
with h5py.File(os.path.join(root_path, 'mitdb', 'all_ecg.hdf5'), 'r') as hdf:
    x = hdf['x'][:]
    y = hdf['y'][:]

# %%
random.seed(2019)
x = np.array(random.choices(x, k=10000))
print(x.shape)
print(y.shape)
# Out:
# (10000, 1, 128)
# (96049,)

# %%
class AvgDownSampler(nn.Module):
    def __init__(self):
        super(AvgDownSampler, self).__init__()
        self.pool = nn.AvgPool1d(2)

    def forward(self, x):
        x = self.pool(x)
        return x.data.numpy().squeeze()

# %%
avg_sampler = AvgDownSampler()

# %%
class EcgConv8(nn.Module):
    def __init__(self):
        super(EcgConv8, self).__init__()
        self.conv1 = nn.Conv1d(1, 16, 7, padding=3)  # 128 x 16        
        self.relu1 = nn.LeakyReLU()
        self.pool1 = nn.MaxPool1d(2)  # 64 x 16
        self.conv2 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu2 = nn.LeakyReLU()        
        self.conv3 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu3 = nn.LeakyReLU()        
        self.conv4 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu4 = nn.LeakyReLU()
        self.conv5 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu5 = nn.LeakyReLU()
        self.conv6 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu6 = nn.LeakyReLU()
        self.conv7 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu7 = nn.LeakyReLU()
        self.conv8 = nn.Conv1d(16, 16, 5, padding=2)  # 64 x 16
        self.relu8 = nn.LeakyReLU()
        self.pool8 = nn.MaxPool1d(2)  # 32 x 16
        self.linear9 = nn.Linear(32 * 16, 128)
        self.relu9 = nn.LeakyReLU()
        self.linear10 = nn.Linear(128, 5)
        self.softmax10 = nn.Softmax(dim=1)
     
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)        
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.conv4(x)
        x = self.relu4(x)
        x = self.conv5(x)
        x = self.relu5(x)
        x = self.conv6(x)
        x = self.relu6(x)
        x = self.conv7(x)
        x = self.relu7(x)
        x = self.conv8(x)
        x = self.relu8(x)
        return x.data.numpy().squeeze()

# %%
ecg_conv8 = EcgConv8()
ecg_conv8.load_state_dict(torch.load(os.path.join(root_path, 'model', 'conv8_0_100.pth'), map_location=torch.device('cpu'))) # conv8_9_best.pth
ecg_conv8.eval()
# Out:
# EcgConv8(
#   (conv1): Conv1d(1, 16, kernel_size=(7,), stride=(1,), padding=(3,))
#   (relu1): LeakyReLU(negative_slope=0.01)
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu2): LeakyReLU(negative_slope=0.01)
#   (conv3): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu3): LeakyReLU(negative_slope=0.01)
#   (conv4): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu4): LeakyReLU(negative_slope=0.01)
#   (conv5): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu5): LeakyReLU(negative_slope=0.01)
#   (conv6): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu6): LeakyReLU(negative_slope=0.01)
#   (conv7): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu7): LeakyReLU(negative_slope=0.01)
#   (conv8): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#   (relu8): LeakyReLU(negative_slope=0.01)
#   (pool8): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (linear9): Linear(in_features=512, out_features=128, bias=True)
#   (relu9): LeakyReLU(negative_slope=0.01)
#   (linear10): Linear(in_features=128, out_features=5, bias=True)
#   (softmax10): Softmax(dim=1)
# )

# %%
dtw_list = [list() for i in range(16)]
dcor_avg_sample = [list() for i in range(16)]
dcor_max_sample = [list() for i in range(16)]

for x_sample in tqdm(x):
    x_tensor = torch.tensor(np.expand_dims(x_sample, axis=0), dtype=torch.float)
    output = ecg_conv8(x_tensor)
    x_avgdown = avg_sampler(x_tensor)
    for i, o in enumerate(output):
        dtw_val = dtw.distance_fast(x_sample.squeeze().astype(np.double), o.astype(np.double))
        dtw_list[i].append(dtw_val)
        dcor_val = dcor.distance_correlation(x_avgdown, o)
        dcor_avg_sample[i].append(dcor_val)
# Out:
# 100%|██████████| 10000/10000 [05:40<00:00, 29.35it/s]

# %%
np.array(dtw_list).shape
# Out:
# (16, 10000)

# %%
sns.set(style='whitegrid', rc={"grid.linewidth": 0.5, 'grid.linestyle': '--'})
dcor_avg_sample = np.array(dcor_avg_sample)
idx = np.argsort(np.mean(dcor_avg_sample, axis=1))[::-1]
dcor_avg_sample = dcor_avg_sample[idx]
fig, ax = plt.subplots(4, 4, figsize=(25, 16))
for i in range(16):
    a = ax[i//4][i%4]
    a.set_title(idx[i])
    a.hist(dcor_avg_sample[i], bins=[0.05 * i for i in range(20)])
    a.set_ylim(0, 3000)
np.savetxt(os.path.join(root_path, 'dtw_dcor', 'conv8_dcor.csv'), dcor_avg_sample, delimiter=",", fmt='%.4f')
np.savetxt(os.path.join(root_path, 'dtw_dcor', 'conv8_dcor_mean.csv'), np.mean(dcor_avg_sample, axis=1), delimiter=",", fmt='%.4f')

# %%
dtw_list = np.array(dtw_list)
idx = np.argsort(np.mean(dtw_list, axis=1))
dtw_list = dtw_list[idx]
fig, ax = plt.subplots(4, 4, figsize=(25, 16))
for i in range(16):
    a = ax[i//4][i%4]
    a.set_title(idx[i])
    a.hist(dtw_list[i], bins=[50 * i for i in range(20)])
    a.set_ylim(0, 3000)
np.savetxt(os.path.join(root_path, 'dtw_dcor', 'conv8_dtw.csv'), dtw_list, delimiter=",", fmt='%.4f')
np.savetxt(os.path.join(root_path, 'dtw_dcor', 'conv8_dtw_mean.csv'), np.mean(dtw_list, axis=1), delimiter=",", fmt='%.4f')
